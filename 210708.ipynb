# %% [markdown]
# <a href="https://colab.research.google.com/github/git933/Computer_Vision/blob/main/210708.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **03 image enhancement**

# %% [markdown]
# - contrast enhancement
# - noise reduction
# - sharpening
# - colorization

# %% [markdown]
# # histogram equalization

# %% [markdown]
# basic procedure
#
# 1. find the accumulated histogram of image intensity
# 2. normalize the accumulated histogram to be probability function
# 3. scale the probability 0~255 usually
# 4. map the intensity into the scaled value in step 4.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # bilateral filter (denoise filter)

# %% [markdown]
# - bilateral filter = domain + range
#
#     noise reduction
#
#     smoothing
#
#     segmentation

# %% [markdown]
# **adaptive bilateral filter**
#
# considering local variance of edges
#
# edge magnitude & preserved edges : 비례
#
# edge orientation

# %% [markdown]
# # median filter

# %% [markdown]
# - filter length should be odd number

# %% [markdown]
# - smooth a few pixels whose values differ significantly from the surrounding, without affecting the other pixels

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# application : salt and pepper / gaussian noise

# %% [markdown]
# # image sharpening using high pass filter

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # image sharpening using unsharp mask

# %% [markdown]
# **laplacian operator** - 2nd
# - finding convex(+ sign) and concave(- sign) geometry

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# edge를 뽑아내서 선명도를 높임

# %% [markdown]
# ---
