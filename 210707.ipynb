# %% [markdown]
# <a href="https://colab.research.google.com/github/git933/Computer_Vision/blob/main/210707.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **06_geometric camera models**

# %% [markdown]
# barrier = 조리개
#
# the image is inverted!

# %% [markdown]
# **perspective effect** = 원근법
#
# - far objects become smaller than closer one
# - two parallel lines intersect at the horizon - in image (vanishing point = point at infinity)

# %% [markdown]
# aperture = 조리개 : **pinhole** size
#
# - pinhole too big : blurring (out-of-focus)
# - pinhole too small : diffraction (blur)

# %% [markdown]
# two pinholes : **stereo camera** (삼각측량)
#
# 물체가 서로 가까이 있을수록 카메라 픽셀 위치 차이가 크다 (반비례 관계)

# %% [markdown]
# - **pinhole** : 크기조절 어려움
#
#     회절유무
#
#   빛의양 조절
#
# - **lens** : 빛의 직진성 유지
#
#     빠른 시간 안에 선명한 상 얻음

# %% [markdown]
# DOF : 독립적인 변수의 개수
#
# HC로 변환할 때 w'이 0이면 평행선들로 이루어진 소실점(infinity)

# %% [markdown]
# **radial distortion** : 중심점 기준으로 방사형으로 뻗어나가는 반지름과 연관됨
#
# 1. barrel distortion
# 2. pincushion distortion
# 3. mustache distortion
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# # **07_camera calibration**

# %% [markdown]
# **calibration problem**
#
# ![image.png](data:image/png;base64,...)
#
# P : known position
#
# p : image
#
# *using least squares method will be efficient*
#
#
# rotaion matrix : 각각의 vector들은 서로 수직
#
# determinant = 1 (물리적인 에너지 고정)

# %% [markdown]
# matlab toolbox : http://www.vision.caltech.edu/bouguetj/calib_doc/

# %% [markdown]
# ---

# %% [markdown]
# # **08_stereo camera**

# %% [markdown]
# **binocular stereogram** : 시차를 이용해 거리감이 있도록 만든 이미지
#
# stereo를 대중적으로 소개함
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **epipolar geometry in 2-view**
#
# p, p' : corresponding point
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# C, C': 중심점 (카메라 렌즈 위치)
#
# essential matrix E : 3*3 matrix

# %% [markdown]
# **rectification**
#
#     making parallel setup
#     image warping
#     3*3 homography

# %% [markdown]
# **stereogram and disparity**
#
# ![image.png](data:image/png;base64,...)
#
# 삼각형의 닮음 이용
#
# z : (z + f) = b : (b + d)
#
# z = fb / d

# %% [markdown]
# -> multi view stereo

# %% [markdown]
# ---

# %% [markdown]
# # **13_Lloyd max quantization (K-means clustering)**

# %% [markdown]
# continuous -> discrete
#
# parameter K = number of clusters
#
# non-uniform quantization

# %% [markdown]
# < procedure >
#
# 1. select K initial centroid vectors
# 2. find the closest vectors for every centroid using Euclidean distances
# 3. Update the centroid of every cluster
# 4. Repeat 2, 3
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# # **14_mean shift(평행 이동)**

# %% [markdown]
# mean shift vector를 center of mass 방향으로 옮겨가면서 density 측정
#
# -> a tool for finding modes in a set of data samples,
#
# manifesting an underlying probability density function (PDF) in Rn
